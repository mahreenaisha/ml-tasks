# %%
from sklearn.datasets import load_iris      # or load_wine

# %%
import pandas as pd

# %%
iris = load_iris()                          # loads toy dataset [web:16][web:19]

# %%
X = iris.data   # features

# %%
y = iris.target # target labels

# %%
df2 = pd.DataFrame(X, columns=iris.feature_names)

# %%
df2["target"] = y

# %%
print(df2.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df2.shape
# Out:
# (150, 5)

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
# shows how many missing (null/NaN) values are in each column.
df2.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df2.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
print(df2.columns)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df2['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
df2['petal length (cm)'].value_counts(normalize=True)
# Out:
# petal length (cm)
# 1.4    0.086667
# 1.5    0.086667
# 4.5    0.053333
# 5.1    0.053333
# 1.3    0.046667
# 1.6    0.046667
# 5.6    0.040000
# 4.9    0.033333
# 4.0    0.033333
# 4.7    0.033333
# 1.7    0.026667
# 4.8    0.026667
# 5.0    0.026667
# 4.4    0.026667
# 4.2    0.026667
# 4.1    0.020000
# 3.9    0.020000
# 5.8    0.020000
# 5.7    0.020000
# 5.5    0.020000
# 6.1    0.020000
# 4.6    0.020000
# 1.9    0.013333
# 5.2    0.013333
# 5.4    0.013333
# 1.2    0.013333
# 3.3    0.013333
# 3.5    0.013333
# 6.7    0.013333
# 5.3    0.013333
# 4.3    0.013333
# 5.9    0.013333
# 6.0    0.013333
# 1.0    0.006667
# 1.1    0.006667
# 3.7    0.006667
# 3.8    0.006667
# 3.6    0.006667
# 3.0    0.006667
# 6.3    0.006667
# 6.6    0.006667
# 6.9    0.006667
# 6.4    0.006667
# Name: proportion, dtype: float64

# %%
df2.isnull().sum()

# %%
df2.corr(numeric_only=True)
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
df2.groupby('species').mean(numeric_only=True)

# %%
df2[df2['sepal length'] > 5.0]

# %%
df2.select_dtypes(include='number').head()

# %%
df2.sort_values('sepal length (cm)')
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 13                 4.3               3.0                1.1               0.1
# 8                  4.4               2.9                1.4               0.2
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 122                7.7               2.8                6.7               2.0
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
#      target
# 13        0
# ...

# %%
df2.nunique()

# %%
df2.rename(columns={'sepal length (cm)': 'sepal_length'}, inplace=False)

# %%
df2['sepal length (cm)'].mean()

# %%
df2['sepal_area'] = df2['sepal length (cm)'] * df2['sepal width (cm)']
